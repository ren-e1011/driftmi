# %%
import pickle

# %%
import numpy as np
import pandas as pd

# %%
loss_train = pickle.load('./losses_train')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 loss_train = pickle.load('./losses_train')
#
# TypeError: file must have 'read' and 'readline' attributes

# %%
with open(r"losses_train", "rb") as input_file:
    loss_train = pickle.load(input_file)

# %%
loss_train
# Out:
#            0
# 0   1.005729
# 1   0.976552
# 2   0.938518
# 3   0.971575
# 4   0.949084
# 5   0.982107
# 6   1.031833
# 7   1.106063
# 8   1.102043
# 9   1.090980
# 10  1.010193
# 11  0.884005
# 12  0.895953
# 13  0.931516
# 14  0.861093
# 15  0.906072
# 16  0.962531
# 17  0.987822
# 18  0.967786
# 19  0.977162
# 20  0.904439
# 21  0.858912
# 22  0.887487
# 23  0.937466
# 24  0.950978
# 25  0.981192
# 26  1.003378
# 27  0.992777
# 28  0.806625
# 29  0.583596
# 30  0.604074
# 31  0.682586
# 32  0.806678
# 33  0.840485
# 34  0.778565
# 35  0.683474
# 36  0.628589
# 37  0.779794
# 38  0.543522
# 39  0.441806
# 40  0.622993
# 41  0.586028
# 42  0.683015
# 43  0.526754
# 44  0.547850
# 45  0.406888
# 46  0.798631
# 47  0.591111
# 48  0.489614
# 49  0.570676
# 50  0.127164
# 51  0.306423
# 52  1.187298
# 53  0.875839
# 54  0.797492
# 55  0.257922
# 56  0.396228
# 57  0.477816
# 58  0.060891
# 59 -0.215557

# %%
with open(r"losses_val", "rb") as input_file:
    loss_val = pickle.load(input_file)

# %%
loss_val
# Out:
#            0
# 0   1.031226
# 1   0.959556
# 2   0.982069
# 3   0.970378
# 4   1.010548
# 5   0.985321
# 6   1.155906
# 7   1.133767
# 8   1.148226
# 9   1.086068
# 10  0.937342
# 11  0.830814
# 12  0.952159
# 13  0.881083
# 14  0.889218
# 15  0.919968
# 16  1.012322
# 17  0.950226
# 18  0.962399
# 19  0.949025
# 20  0.834773
# 21  0.836066
# 22  0.893420
# 23  0.944090
# 24  0.933344
# 25  1.023751
# 26  1.004830
# 27  0.932143
# 28  0.658522
# 29  0.515330
# 30  0.617838
# 31  0.764397
# 32  0.830797
# 33  0.798014
# 34  0.713619
# 35  0.624353
# 36  0.625687
# 37  0.710145
# 38  0.327836
# 39  0.421656
# 40  0.492231
# 41  0.558532
# 42  0.507205
# 43  0.469122
# 44  0.290967
# 45  0.302896
# 46  0.520562
# 47  0.555739
# 48  0.242000
# 49  0.508462
# 50 -0.290747
# 51  0.774353
# 52  0.793806
# 53  0.648058
# 54  0.652095
# 55  0.189949
# 56  0.353700
# 57  0.298816
# 58 -0.441849
# 59  0.148582

# %%
with open(r"results_train", "rb") as input_file:
    res_train = pickle.load(input_file)

# %%
with open(r"results_val", "rb") as input_file:
    res_val = pickle.load(input_file)

# %%
res_train
# Out:
#            0
# 0  -0.007095
# 1  -0.003316
# 2  -0.003375
# 3   0.003375
# 4   0.004617
# 5   0.015863
# 6   0.000044
# 7   0.001893
# 8   0.018088
# 9   0.009223
# 10  0.013491
# 11  0.004602
# 12  0.015103
# 13  0.011191
# 14  0.022548
# 15  0.027957
# 16  0.025730
# 17  0.027033
# 18  0.029958
# 19  0.038001
# 20  0.056988
# 21  0.035635
# 22  0.033788
# 23  0.047183
# 24  0.019678
# 25  0.065827
# 26  0.063184
# 27  0.063315
# 28  0.049119
# 29  0.042482
# 30  0.041613
# 31  0.056936
# 32  0.056541
# 33  0.084279
# 34  0.115767
# 35  0.091364
# 36  0.097835
# 37  0.097216
# 38  0.119017
# 39  0.091430
# 40  0.147264
# 41  0.147188
# 42  0.161674
# 43  0.169242
# 44  0.194916
# 45  0.173779
# 46  0.181885
# 47  0.224838
# 48  0.177470
# 49  0.193188
# 50  0.285242
# 51  0.233987
# 52  0.231992
# 53  0.285612
# 54  0.328422
# 55  0.253849
# 56  0.285675
# 57  0.300617
# 58  0.348047
# 59  0.360751

# %%
res_val
# Out:
#            0
# 0  -0.033117
# 1  -0.015189
# 2  -0.006046
# 3  -0.001452
# 4   0.024339
# 5   0.028367
# 6  -0.032304
# 7  -0.025101
# 8   0.007253
# 9  -0.034444
# 10  0.053559
# 11  0.027965
# 12 -0.021320
# 13 -0.047821
# 14 -0.011505
# 15  0.081357
# 16  0.033149
# 17  0.086214
# 18 -0.050575
# 19  0.045765
# 20  0.079698
# 21  0.087425
# 22  0.026065
# 23  0.113407
# 24  0.026881
# 25  0.067591
# 26  0.134091
# 27 -0.061234
# 28  0.030849
# 29  0.096600
# 30  0.144238
# 31  0.160536
# 32  0.088416
# 33  0.113044
# 34  0.205100
# 35  0.159235
# 36  0.293652
# 37  0.215890
# 38  0.234634
# 39  0.242647
# 40  0.370951
# 41 -0.064395
# 42  0.253552
# 43  0.333528
# 44  0.392154
# 45  0.561790
# 46  0.288680
# 47  0.201585
# 48  0.299463
# 49  0.230842
# 50  0.381016
# 51  0.094735
# 52  0.531332
# 53  0.430906
# 54  0.518731
# 55  0.530931
# 56  0.070297
# 57  0.256774
# 58  0.524806
# 59  0.617041

# %%
eval_df = pd.DataFrame({'LossTrain':np.array(loss_train[0]), 'LossVal':np.array(loss_val[0]), 'ResTrain':np.array(res_train[0]),'ResVal':np.array(res_val[0])})

# %%
eval_df.head()
# Out:
#    LossTrain   LossVal  ResTrain    ResVal
# 0   1.005729  1.031226 -0.007095 -0.033117
# 1   0.976552  0.959556 -0.003316 -0.015189
# 2   0.938518  0.982069 -0.003375 -0.006046
# 3   0.971575  0.970378  0.003375 -0.001452
# 4   0.949084  1.010548  0.004617  0.024339

# %%
eval_df.plot(figsize=(15,10))
# Out:
# <AxesSubplot:>
